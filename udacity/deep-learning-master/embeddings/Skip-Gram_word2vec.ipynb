# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

treshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1-np.sqrt(treshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if p_drop[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6756 0.2850 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6194 0.2524 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5380 0.2712 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6014 0.2810 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5211 0.2461 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5465 0.2326 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5502 0.2365 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5460 0.2311 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4843 0.2468 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4238 0.2703 sec/batch
# Nearest to one: cryptologia, lepanto, epp, valued, antients, poorest, knight, neri,
# Nearest to called: reis, wannsee, padova, feeling, wideband, victory, mourning, systemic,
# Nearest to it: marginalised, decrease, mishnah, arminianism, explicated, vicente, minimising, synod,
# Nearest to seven: stormbl, strathclyde, alastair, smolensk, g, samples, homophobic, westmoreland,
# Nearest to there: manatee, tongs, upc, towering, surreal, carina, rosenfeld, execute,
# Nearest to these: cutting, kol, corelli, assizes, disappeared, stroheim, collides, pulled,
# Nearest to he: shotgun, hare, yemenite, redevelop, ba, enriched, untold, palenque,
# Nearest to will: marathon, jumped, great, catalyze, substance, epitome, sylia, phases,
# Nearest to marriage: moran, popularize, grammys, tano, yaound, gifs, ehret, mjt,
# Nearest to consists: messiaen, hillsdale, social, large, dkp, confessing, sagan, ayub,
# Nearest to behind: cucumbers, stings, shahi, epsilon, myspace, properly, suspends, rsi,
# Nearest to governor: semantic, frey, dur, warszawa, willamette, ainu, campylobacter, atocha,
# Nearest to shown: massed, arbitration, reluctantly, priestess, stews, morden, cellphone, welwyn,
# Nearest to operations: sauvage, industrialisation, forl, repair, assault, sacraments, carriage, looser,
# Nearest to heavy: guilty, nek, sacu, alpina, familiarize, edd, obliterating, pokemon,
# Nearest to active: bookmakers, crewmembers, fighting, agni, whichever, appellation, agathocles, widening,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4861 0.2550 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3704 0.3078 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3340 0.2387 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2627 0.2354 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1994 0.2341 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1897 0.2349 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1216 0.2361 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0936 0.2878 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0021 0.2277 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9864 0.2265 sec/batch
# Nearest to one: cryptologia, valued, begun, governed, original, adjective, air, lepanto,
# Nearest to called: victory, rules, product, spring, wannsee, the, feeling, residing,
# Nearest to it: decrease, marginalised, certain, settlements, eds, mishnah, consent, explicated,
# Nearest to seven: samples, stormbl, g, strathclyde, development, apparently, alastair, attracted,
# Nearest to there: upc, manatee, tongs, execute, surreal, want, part, somewhere,
# Nearest to these: cutting, disappeared, enzymes, pulled, autocode, practitioner, worldwide, presse,
# Nearest to he: hare, shotgun, strait, ba, budget, redevelop, activities, baby,
# Nearest to will: substance, great, access, jumped, marathon, catalyze, lovin, eye,
# Nearest to marriage: moran, popularize, ehret, gifs, mjt, exploring, succeeds, grammys,
# Nearest to consists: social, messiaen, large, hillsdale, ultraviolet, sagan, position, zr,
# Nearest to behind: epsilon, cucumbers, properly, staff, shahi, stands, off, suspends,
# Nearest to governor: semantic, frey, dur, hates, jonson, canada, willamette, ainu,
# Nearest to shown: arbitration, massed, priestess, glens, reluctantly, cellphone, disease, harbours,
# Nearest to operations: sauvage, repair, industrialisation, forl, zeitgeist, carriage, encountered, invented,
# Nearest to heavy: guilty, comedy, earn, nek, unaccounted, imprecise, entitled, integration,
# Nearest to active: crewmembers, fighting, bookmakers, widening, whichever, preference, disgraced, worshipper,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9302 0.2472 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9166 0.2337 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8887 0.2165 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8657 0.2428 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8360 0.2312 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8162 0.2384 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8043 0.2389 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8016 0.2117 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7692 0.2186 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7803 0.2406 sec/batch
# Nearest to one: cryptologia, begun, three, adjective, valued, zero, james, redeveloped,
# Nearest to called: wannsee, feeling, victory, mourning, rules, spring, rip, attribute,
# Nearest to it: decrease, marginalised, eds, consent, synod, mishnah, settlements, explicated,
# Nearest to seven: samples, alastair, stormbl, apparently, strathclyde, collections, ines, attracted,
# Nearest to there: upc, manatee, execute, tongs, surreal, perth, lobbied, towering,
# Nearest to these: cutting, disappeared, enzymes, presse, canton, analysing, pulled, autocode,
# Nearest to he: shotgun, hare, ba, baby, save, yemenite, responsibilities, strait,
# Nearest to will: substance, jumped, marathon, great, access, phases, lovin, eye,
# Nearest to marriage: moran, popularize, gifs, exploring, sharing, ehret, exacted, victor,
# Nearest to consists: messiaen, social, hillsdale, large, confessing, sagan, laboratory, advise,
# Nearest to behind: properly, epsilon, cucumbers, married, logos, staff, suspends, shahi,
# Nearest to governor: semantic, canada, hates, enjoyed, inquisition, keep, jonson, dur,
# Nearest to shown: massed, arbitration, reluctantly, priestess, glens, thrown, harbours, cellphone,
# Nearest to operations: repair, sauvage, industrialisation, carriage, unanimous, assault, iterative, encountered,
# Nearest to heavy: guilty, nek, integration, earn, familiarize, comedy, respectful, edd,
# Nearest to active: fighting, crewmembers, bookmakers, widening, preference, whichever, difficulty, rj,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7916 0.2085 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7529 0.2272 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7092 0.2142 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6994 0.2007 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7431 0.2119 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6893 0.1968 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7231 0.1963 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7291 0.2518 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6869 0.2456 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6460 0.2433 sec/batch
# Nearest to one: three, zero, cryptologia, six, italian, german, james, francis,
# Nearest to called: wannsee, feeling, mourning, victory, rules, rip, product, systemic,
# Nearest to it: decrease, marginalised, mishnah, eds, consent, minimising, explicated, proof,
# Nearest to seven: two, samples, aw, english, isbn, alastair, prestigious, zero,
# Nearest to there: upc, manatee, tongs, perth, execute, surreal, towering, drain,
# Nearest to these: cutting, disappeared, presse, enzymes, canton, analysing, inconspicuous, kol,
# Nearest to he: yemenite, shotgun, enriched, ba, baby, responsibilities, alison, hare,
# Nearest to will: jumped, substance, access, marathon, baserunner, eye, indent, lovin,
# Nearest to marriage: moran, popularize, imitated, exacted, gifs, succeeds, ekspres, exploring,
# Nearest to consists: messiaen, hillsdale, confessing, social, large, londinium, ayub, sagan,
# Nearest to behind: properly, epsilon, suspends, cucumbers, naturalised, logos, stings, onomatopoeic,
# Nearest to governor: semantic, canada, enjoyed, inquisition, hates, jonson, dur, lightning,
# Nearest to shown: massed, arbitration, reluctantly, priestess, glens, harbours, stews, cellphone,
# Nearest to operations: sauvage, industrialisation, repair, assault, carriage, unanimous, looser, iterative,
# Nearest to heavy: guilty, nek, guano, familiarize, apologetic, alpina, respectful, integration,
# Nearest to active: bookmakers, fighting, crewmembers, rj, preference, whichever, extraterrestrials, worshipper,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6765 0.2658 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6626 0.2549 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6144 0.2303 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6345 0.2701 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6505 0.2369 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6380 0.2406 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6137 0.1827 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5573 0.2138 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5263 0.1938 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5198 0.1929 sec/batch
# Nearest to one: three, zero, six, german, composer, italian, seven, cryptologia,
# Nearest to called: wannsee, product, rules, filters, vanish, systemic, feeling, rip,
# Nearest to it: decrease, marginalised, mishnah, explicated, minimising, eds, methodius, consent,
# Nearest to seven: two, one, zero, eight, english, aw, isbn, b,
# Nearest to there: manatee, upc, execute, tongs, refutations, surreal, serpentine, perth,
# Nearest to these: cutting, enzymes, analysing, disappeared, inconspicuous, presse, kol, autocode,
# Nearest to he: yemenite, save, alison, godzilla, enriched, shotgun, baby, pope,
# Nearest to will: jumped, access, substance, marathon, lovin, baserunner, eye, indent,
# Nearest to marriage: moran, popularize, exacted, imitated, succeeds, mjt, gifs, lucius,
# Nearest to consists: messiaen, hillsdale, ayub, confessing, large, londinium, sagan, social,
# Nearest to behind: epsilon, properly, naturalised, cucumbers, heraclitus, suspends, stings, intersecting,
# Nearest to governor: canada, inquisition, semantic, enjoyed, dur, jonson, carrie, lightning,
# Nearest to shown: arbitration, massed, numbers, reluctantly, priestess, stews, spectral, cellphone,
# Nearest to operations: sauvage, repair, industrialisation, assault, carriage, looser, iterative, rol,
# Nearest to heavy: nek, guilty, guano, alpina, familiarize, apologetic, edd, unreactive,
# Nearest to active: crewmembers, fighting, bookmakers, whichever, appellation, extraterrestrials, rj, disgraced,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4885 0.1973 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4800 0.2353 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4480 0.2343 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5164 0.2339 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4657 0.2312 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4567 0.2328 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4387 0.2400 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3779 0.2683 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4179 0.2548 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4385 0.2311 sec/batch
# Nearest to one: three, zero, cryptologia, six, leonid, lepanto, redeveloped, argentina,
# Nearest to called: product, wannsee, vanish, the, rip, filters, systemic, weren,
# Nearest to it: decrease, marginalised, explicated, mishnah, consent, sadie, arminianism, given,
# Nearest to seven: two, zero, sq, one, flavianum, godly, alastair, samples,
# Nearest to there: manatee, upc, serpentine, execute, perth, tongs, refutations, surreal,
# Nearest to these: cutting, enzymes, analysing, presse, disappeared, inconspicuous, autocode, kol,
# Nearest to he: godzilla, yemenite, alison, save, shotgun, baby, lenny, took,
# Nearest to will: jumped, substance, access, indent, eye, marathon, baserunner, lovin,
# Nearest to marriage: moran, popularize, exacted, succeeds, imitated, romanorum, gifs, mjt,
# Nearest to consists: messiaen, confessing, hillsdale, ayub, large, sagan, dkp, londinium,
# Nearest to behind: stings, epsilon, suspends, naturalised, properly, knowbot, heraclitus, onomatopoeic,
# Nearest to governor: canada, presidential, dur, inquisition, carrie, janssen, enjoyed, hates,
# Nearest to shown: massed, arbitration, numbers, spectral, reluctantly, infty, morden, cellphone,
# Nearest to operations: sauvage, repair, assault, industrialisation, looser, tren, carriage, rol,
# Nearest to heavy: familiarize, nek, alpina, guano, guided, unreactive, regulator, drink,
# Nearest to active: crewmembers, bookmakers, fighting, rj, appellation, extraterrestrials, whichever, preference,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4614 0.2605 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4033 0.2549 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4162 0.2534 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3771 0.2526 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4235 0.2493 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4306 0.2173 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3638 0.1934 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3716 0.1923 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4184 0.1942 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3812 0.1927 sec/batch
# Nearest to one: three, zero, six, cryptologia, seven, leonid, lepanto, redeveloped,
# Nearest to called: wannsee, product, rip, the, startled, weren, filters, systemic,
# Nearest to it: decrease, marginalised, explicated, worthless, mishnah, arminianism, obligatory, consent,
# Nearest to seven: two, zero, one, isbn, eight, rickey, alastair, aw,
# Nearest to there: manatee, upc, serpentine, tongs, perth, surreal, refutations, execute,
# Nearest to these: cutting, enzymes, analysing, disappeared, inconspicuous, ptb, presse, kol,
# Nearest to he: alison, yemenite, godzilla, lenny, baby, save, circumnavigation, took,
# Nearest to will: jumped, indent, access, substance, eye, marathon, baserunner, catalyze,
# Nearest to marriage: moran, popularize, exacted, imitated, romanorum, grammys, lucius, succeeds,
# Nearest to consists: ayub, messiaen, confessing, hillsdale, large, londinium, sagan, dkp,
# Nearest to behind: stings, onomatopoeic, naturalised, suspends, epsilon, overhead, intersecting, properly,
# Nearest to governor: canada, presidential, dur, khan, janssen, mancha, embassy, willamette,
# Nearest to shown: massed, arbitration, infty, spectral, numbers, reluctantly, thrown, morden,
# Nearest to operations: sauvage, repair, assault, industrialisation, looser, tren, fijian, rol,
# Nearest to heavy: alpina, familiarize, guided, nek, guano, drink, unreactive, regulator,
# Nearest to active: bookmakers, crewmembers, rj, fighting, appellation, whichever, extraterrestrials, executing,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3541 0.1959 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4119 0.1937 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3957 0.1937 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3810 0.1934 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4193 0.1933 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3737 0.1942 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3895 0.1930 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4149 0.1922 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3140 0.1922 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3318 0.1918 sec/batch
# Nearest to one: three, zero, six, cryptologia, seven, lepanto, redeveloped, argentina,
# Nearest to called: wannsee, the, rip, product, startled, weren, magnets, soichiro,
# Nearest to it: decrease, explicated, marginalised, consent, arminianism, obligatory, mishnah, priori,
# Nearest to seven: two, zero, eight, one, megawati, six, isbn, sq,
# Nearest to there: manatee, upc, tongs, perth, homeric, lobbied, surreal, serpentine,
# Nearest to these: cutting, disappeared, enzymes, analysing, inconspicuous, ptb, corelli, commutative,
# Nearest to he: alison, yemenite, circumnavigation, lenny, godzilla, enriched, ransom, wished,
# Nearest to will: jumped, indent, access, eye, marathon, baserunner, catalyze, substance,
# Nearest to marriage: moran, popularize, romanorum, exacted, imitated, grammys, lucius, gifs,
# Nearest to consists: ayub, messiaen, rede, sagan, hillsdale, dkp, large, londinium,
# Nearest to behind: stings, naturalised, onomatopoeic, overhead, knowbot, suspends, intersecting, slap,
# Nearest to governor: khan, presidential, dur, canada, mancha, cabinet, gays, embassy,
# Nearest to shown: massed, arbitration, thrown, infty, reluctantly, mansur, spectral, morden,
# Nearest to operations: sauvage, assault, repair, fijian, looser, industrialisation, tren, rol,
# Nearest to heavy: alpina, guided, familiarize, guano, unreactive, nek, curtis, drink,
# Nearest to active: bookmakers, crewmembers, rj, fighting, extraterrestrials, fruitarians, appellation, whichever,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3323 0.1973 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3123 0.1933 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3391 0.1938 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3643 0.1931 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3880 0.2241 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2781 0.2035 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3026 0.2624 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3623 0.2740 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2249 0.2689 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3101 0.2515 sec/batch
# Nearest to one: three, zero, six, seven, four, eight, cryptologia, composer,
# Nearest to called: wannsee, rip, the, product, cotten, magnets, filters, soichiro,
# Nearest to it: decrease, marginalised, explicated, obligatory, consent, priori, arminianism, up,
# Nearest to seven: two, zero, one, eight, six, trajkovski, three, five,
# Nearest to there: manatee, upc, tongs, lobbied, surreal, conventionally, homeric, swampy,
# Nearest to these: cutting, enzymes, analysing, disappeared, inconspicuous, ptb, practitioner, corelli,
# Nearest to he: lenny, alison, circumnavigation, yemenite, godzilla, his, cordon, shotgun,
# Nearest to will: jumped, indent, access, eye, lani, marathon, substance, reach,
# Nearest to marriage: moran, popularize, exacted, imitated, romanorum, grammys, gifs, mentally,
# Nearest to consists: rede, hillsdale, messiaen, ayub, large, londinium, dkp, sagan,
# Nearest to behind: stings, naturalised, onomatopoeic, properly, intersecting, logos, overhead, off,
# Nearest to governor: presidential, canada, khan, dur, cabinet, mancha, gays, republican,
# Nearest to shown: massed, arbitration, numbers, infty, spectral, stews, reluctantly, thrown,
# Nearest to operations: sauvage, assault, repair, fijian, looser, security, tren, sharpened,
# Nearest to heavy: alpina, guided, guano, familiarize, curtis, unreactive, nek, drink,
# Nearest to active: bookmakers, fighting, rj, crewmembers, proterozoic, appellation, whichever, fruitarians,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3023 0.2389 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3123 0.2423 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3102 0.1127 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2623 0.2448 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2164 0.2313 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1924 0.2360 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2146 0.2345 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2163 0.2264 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2458 0.2314 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1772 0.2598 sec/batch
# Nearest to one: three, zero, six, seven, four, leonid, cryptologia, eight,
# Nearest to called: wannsee, the, startled, cotten, rip, callisthenes, sadat, magnets,
# Nearest to it: decrease, marginalised, explicated, obligatory, consent, salamanders, levelling, microcontroller,
# Nearest to seven: two, one, zero, eight, six, trajkovski, three, lemmon,
# Nearest to there: manatee, serpentine, tongs, upc, swampy, present, lobbied, surreal,
# Nearest to these: cutting, disappeared, analysing, enzymes, ptb, corelli, inconspicuous, mormon,
# Nearest to he: his, circumnavigation, yemenite, godzilla, lenny, alison, wished, him,
# Nearest to will: jumped, indent, reach, marathon, lani, eye, baserunner, access,
# Nearest to marriage: moran, popularize, romanorum, mentally, lucius, disgust, gifs, exacted,
# Nearest to consists: rede, hillsdale, dkp, large, sagan, messiaen, parliament, smeaton,
# Nearest to behind: naturalised, overhead, stings, slap, onomatopoeic, intersecting, off, advancing,
# Nearest to governor: presidential, canada, dur, gays, janssen, republican, hails, cabinet,
# Nearest to shown: massed, numbers, infty, arbitration, thrown, spectral, stews, reluctantly,
# Nearest to operations: sauvage, assault, tren, sharpened, fijian, hc, repair, carriage,
# Nearest to heavy: guided, alpina, guano, unreactive, familiarize, curtis, nek, icsu,
# Nearest to active: bookmakers, rj, crewmembers, appellation, fighting, proterozoic, widening, fruitarians,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2066 0.2143 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2250 0.2131 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2259 0.2424 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1287 0.2277 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2126 0.2223 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1681 0.2171 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1637 0.1934 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1681 0.1915 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2017 0.2177 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1667 0.2293 sec/batch
# Nearest to one: three, zero, six, seven, leonid, four, cryptologia, est,
# Nearest to called: wannsee, the, startled, rip, cotten, button, callisthenes, magnets,
# Nearest to it: decrease, explicated, consent, obligatory, microcontroller, marginalised, salamanders, worthless,
# Nearest to seven: two, zero, one, eight, trajkovski, six, three, megawati,
# Nearest to there: manatee, tongs, serpentine, upc, conventionally, surreal, swampy, homeric,
# Nearest to these: cutting, enzymes, analysing, ptb, disappeared, inconspicuous, mormon, judi,
# Nearest to he: his, circumnavigation, alison, godzilla, yemenite, lenny, him, never,
# Nearest to will: jumped, indent, reach, eye, baserunner, ragged, sequentially, catalyze,
# Nearest to marriage: moran, mentally, romanorum, popularize, lucius, exacted, imitated, disgust,
# Nearest to consists: rede, dkp, large, hillsdale, zhdanov, decreasing, messiaen, parliament,
# Nearest to behind: slap, overhead, naturalised, stings, redoutable, off, advancing, intersecting,
# Nearest to governor: canada, presidential, hails, dur, republican, cabinet, gays, defensible,
# Nearest to shown: massed, reluctantly, thrown, arbitration, infty, stews, trellis, prosigns,
# Nearest to operations: sauvage, assault, security, tren, fijian, hc, agencies, sharpened,
# Nearest to heavy: alpina, guided, guano, curtis, unreactive, familiarize, drink, nek,
# Nearest to active: bookmakers, rj, appellation, ascetics, proterozoic, fruitarians, crewmembers, fighting,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1776 0.2314 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2112 0.2311 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1637 0.2194 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1505 0.2319 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1754 0.2275 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1963 0.2490 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2069 0.2182 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1700 0.2322 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1525 0.2345 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1684 0.2386 sec/batch
# Nearest to one: three, zero, six, seven, four, leonid, eight, five,
# Nearest to called: wannsee, the, callisthenes, cotten, rip, startled, verso, button,
# Nearest to it: decrease, explicated, obligatory, consent, marginalised, worthless, salamanders, voluntarily,
# Nearest to seven: zero, two, one, eight, six, three, trajkovski, five,
# Nearest to there: serpentine, conventionally, upc, manatee, surreal, lobbied, tongs, homeric,
# Nearest to these: cutting, enzymes, analysing, ptb, disappeared, inconspicuous, mormon, canton,
# Nearest to he: his, circumnavigation, godzilla, yemenite, alison, lenny, him, wished,
# Nearest to will: jumped, indent, reach, ragged, sequentially, shots, baserunner, identification,
# Nearest to marriage: mentally, moran, romanorum, popularize, imitated, lucius, disgust, gifs,
# Nearest to consists: rede, hillsdale, parliament, dkp, zhdanov, large, messiaen, sagan,
# Nearest to behind: overhead, stings, naturalised, slap, redoutable, onomatopoeic, advancing, off,
# Nearest to governor: presidential, canada, hails, dur, cabinet, gays, republican, janssen,
# Nearest to shown: massed, trellis, thrown, arbitration, reluctantly, huntley, infty, stews,
# Nearest to operations: sauvage, assault, security, operation, numbers, fijian, agencies, tren,
# Nearest to heavy: alpina, guided, guano, unreactive, curtis, familiarize, nek, deuterium,
# Nearest to active: bookmakers, rj, proterozoic, appellation, ascetics, fighting, crewmembers, scorpio,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2049 0.2394 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1857 0.2355 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1712 0.2283 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1916 0.2243 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1438 0.1988 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1216 0.1958 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1665 0.1960 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1192 0.1976 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1881 0.1958 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2156 0.1958 sec/batch
# Nearest to one: three, zero, six, seven, four, five, eight, leonid,
# Nearest to called: wannsee, the, callisthenes, mourning, spring, provincial, cotten, weren,
# Nearest to it: consent, explicated, decrease, obligatory, worthless, voluntarily, marginalised, synod,
# Nearest to seven: zero, one, two, eight, six, three, trajkovski, five,
# Nearest to there: homeric, serpentine, tongs, upc, manatee, palatable, surreal, convenience,
# Nearest to these: cutting, ptb, disappeared, mormon, canton, inconspicuous, analysing, enzymes,
# Nearest to he: his, circumnavigation, alison, him, lenny, sonnet, godzilla, alsatian,
# Nearest to will: jumped, indent, ragged, reach, lani, baserunner, eye, indelible,
# Nearest to marriage: mentally, moran, romanorum, disgust, beaumarchais, lucius, gifs, imitated,
# Nearest to consists: rede, hillsdale, dkp, parliament, zhdanov, sagan, messiaen, smeaton,
# Nearest to behind: naturalised, stings, advancing, packers, slap, overhead, logos, shoots,
# Nearest to governor: presidential, canada, hails, dur, cabinet, aravalli, republican, semantic,
# Nearest to shown: massed, trellis, thrown, arbitration, allenby, huntley, stews, reluctantly,
# Nearest to operations: sauvage, assault, fijian, security, agencies, operation, repair, staff,
# Nearest to heavy: curtis, alpina, unreactive, guided, guano, deuterium, phalanx, gilmour,
# Nearest to active: bookmakers, rj, proterozoic, ascetics, appellation, scorpio, tucum, chair,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2388 0.1988 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1243 0.1955 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1517 0.1938 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1522 0.2050 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0042 0.1934 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1605 0.1971 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1140 0.1945 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1538 0.1935 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1847 0.0426 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0972 0.1941 sec/batch
# Nearest to one: three, zero, six, seven, four, five, est, eight,
# Nearest to called: wannsee, the, callisthenes, provincial, generalised, cotten, startled, spring,
# Nearest to it: decrease, explicated, obligatory, microcontroller, voluntarily, up, worthless, marginalised,
# Nearest to seven: zero, one, two, eight, six, three, five, four,
# Nearest to there: serpentine, lobbied, upc, truetype, swampy, manatee, tongs, present,
# Nearest to these: cutting, enzymes, analysing, ptb, disappeared, mormon, demyelination, inconspicuous,
# Nearest to he: his, circumnavigation, him, lenny, alison, devour, godzilla, sonnet,
# Nearest to will: jumped, indent, ragged, eye, reach, sequentially, does, substance,
# Nearest to marriage: mentally, moran, disgust, romanorum, gifs, couples, lucius, beaumarchais,
# Nearest to consists: rede, parliament, dkp, zhdanov, hillsdale, large, messiaen, decreasing,
# Nearest to behind: naturalised, packers, slap, advancing, erupts, logos, overhead, apparent,
# Nearest to governor: dur, canada, semantic, hails, presidential, defensible, cabinet, aravalli,
# Nearest to shown: trellis, stews, huntley, numbers, massed, allenby, prosigns, arbitration,
# Nearest to operations: sauvage, assault, fijian, numbers, operation, agencies, hc, security,
# Nearest to heavy: curtis, alpina, unreactive, guided, gilmour, deuterium, phalanx, guano,
# Nearest to active: bookmakers, rj, proterozoic, ascetics, appellation, scorpio, tucum, fruitarians,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0901 0.1995 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0936 0.1943 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0630 0.1936 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0377 0.1935 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0687 0.1940 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0504 0.1930 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0934 0.1943 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0701 0.1944 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1127 0.1938 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0121 0.1934 sec/batch
# Nearest to one: three, zero, six, seven, four, five, eight, est,
# Nearest to called: wannsee, the, provincial, startled, spring, callisthenes, cotten, button,
# Nearest to it: decrease, microcontroller, explicated, obligatory, capability, phase, axopods, salamanders,
# Nearest to seven: zero, two, one, eight, six, three, four, five,
# Nearest to there: serpentine, surreal, tongs, upc, conventionally, convenience, present, perth,
# Nearest to these: cutting, enzymes, disappeared, ptb, analysing, mormon, canton, inconspicuous,
# Nearest to he: his, him, circumnavigation, lenny, alsatian, sonnet, never, cordon,
# Nearest to will: jumped, indent, ragged, reach, eye, indelible, alist, baserunner,
# Nearest to marriage: mentally, moran, romanorum, disgust, gifs, beaumarchais, couples, lucius,
# Nearest to consists: rede, parliament, dkp, zhdanov, hillsdale, sagan, large, pechenegs,
# Nearest to behind: packers, the, naturalised, overhead, advancing, redoutable, intersecting, slap,
# Nearest to governor: canada, semantic, dur, hails, aired, aravalli, defensible, syndicated,
# Nearest to shown: trellis, massed, prosigns, prefering, arbitration, allenby, huntley, stews,
# Nearest to operations: sauvage, assault, operation, numbers, fijian, security, mapped, tren,
# Nearest to heavy: alpina, curtis, guided, unreactive, gilmour, phalanx, raider, deuterium,
# Nearest to active: bookmakers, rj, appellation, proterozoic, ascetics, scorpio, fruitarians, tucum,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0334 0.1988 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0500 0.1941 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0297 0.1938 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0491 0.1948 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0776 0.2355 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0652 0.2055 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0763 0.2112 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1016 0.2221 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0354 0.2204 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0350 0.2139 sec/batch
# Nearest to one: three, zero, six, seven, four, five, eight, est,
# Nearest to called: the, wannsee, startled, cotten, it, callisthenes, provincial, rip,
# Nearest to it: decrease, obligatory, explicated, microcontroller, phase, capability, worthless, voluntarily,
# Nearest to seven: zero, one, two, eight, six, five, three, four,
# Nearest to there: serpentine, convenience, palatable, upc, tongs, surreal, truetype, lobbied,
# Nearest to these: enzymes, cutting, analysing, ptb, disappeared, mormon, corelli, inconspicuous,
# Nearest to he: his, him, circumnavigation, lenny, alison, sonnet, jude, godzilla,
# Nearest to will: jumped, indent, ragged, reach, sequentially, eye, substance, does,
# Nearest to marriage: mentally, romanorum, moran, beaumarchais, bile, couples, gifs, disgust,
# Nearest to consists: rede, parliament, dkp, zhdanov, hillsdale, side, sagan, decreasing,
# Nearest to behind: overhead, naturalised, intersecting, packers, redoutable, slap, advancing, logos,
# Nearest to governor: semantic, canada, hails, aired, dur, defensible, ilois, aravalli,
# Nearest to shown: trellis, allenby, prefering, numbers, prosigns, huntley, arbitration, massed,
# Nearest to operations: sauvage, assault, numbers, operation, mapped, security, tren, agencies,
# Nearest to heavy: alpina, curtis, unreactive, deuterium, phalanx, raider, guided, gilmour,
# Nearest to active: bookmakers, rj, proterozoic, ascetics, appellation, scorpio, fruitarians, tucum,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0453 0.2823 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0853 0.2711 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0805 0.2622 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0510 0.2297 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0667 0.2071 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0571 0.2096 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0514 0.2255 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0506 0.2331 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0838 0.2253 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0772 0.2644 sec/batch
# Nearest to one: three, zero, six, seven, five, four, eight, nine,
# Nearest to called: wannsee, the, provincial, callisthenes, generalised, it, differing, spring,
# Nearest to it: obligatory, explicated, decrease, capability, microcontroller, phase, voluntarily, synod,
# Nearest to seven: zero, two, one, eight, six, three, five, four,
# Nearest to there: palatable, lobbied, upc, tongs, convenience, serpentine, surreal, present,
# Nearest to these: cutting, mormon, inconspicuous, enzymes, disappeared, canton, ptb, corelli,
# Nearest to he: his, him, alsatian, circumnavigation, alison, sonnet, shays, never,
# Nearest to will: jumped, indent, ragged, does, messiahs, excised, reach, eye,
# Nearest to marriage: mentally, romanorum, beaumarchais, moran, disgust, couples, bile, scorn,
# Nearest to consists: rede, parliament, dkp, zhdanov, hillsdale, multiplicity, sagan, side,
# Nearest to behind: overhead, naturalised, logos, packers, intersecting, redoutable, onomatopoeic, shoots,
# Nearest to governor: hails, semantic, canada, aired, ilois, headroom, syndicated, aravalli,
# Nearest to shown: trellis, allenby, prefering, fpga, huntley, stews, prosigns, arbitration,
# Nearest to operations: sauvage, assault, operation, numbers, security, agencies, repair, staff,
# Nearest to heavy: unreactive, curtis, alpina, deuterium, phalanx, raider, icsu, however,
# Nearest to active: bookmakers, rj, ascetics, proterozoic, scorpio, appellation, tucum, fruitarians,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0518 0.2130 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0033 0.1996 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0476 0.2017 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0587 0.2311 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0759 0.2282 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1091 0.2305 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1199 0.2164 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0199 0.2449 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0250 0.2255 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0660 0.2085 sec/batch
# Nearest to one: three, zero, six, seven, four, five, eight, nine,
# Nearest to called: wannsee, the, rip, cotten, spring, it, provincial, drenched,
# Nearest to it: obligatory, microcontroller, capability, phase, explicated, up, decrease, voluntarily,
# Nearest to seven: zero, one, two, eight, six, three, five, four,
# Nearest to there: upc, palatable, convenience, surreal, tongs, are, present, truetype,
# Nearest to these: cutting, mormon, ptb, canton, enzymes, inconspicuous, disappeared, analysing,
# Nearest to he: his, him, alsatian, circumnavigation, graduated, sonnet, shays, returned,
# Nearest to will: jumped, indent, ragged, does, sequentially, reach, messiahs, eye,
# Nearest to marriage: mentally, beaumarchais, moran, couples, disgust, romanorum, mjt, gifs,
# Nearest to consists: rede, parliament, dkp, zhdanov, hillsdale, hv, datagram, cidade,
# Nearest to behind: logos, overhead, naturalised, intersecting, heraclitus, onomatopoeic, advancing, erupts,
# Nearest to governor: canada, aired, hails, ilois, syndicated, semantic, aravalli, mancha,
# Nearest to shown: trellis, numbers, huntley, allenby, fpga, alif, prefering, prosigns,
# Nearest to operations: sauvage, operation, assault, numbers, repair, agencies, security, tren,
# Nearest to heavy: curtis, alpina, unreactive, deuterium, phalanx, however, gilmour, raider,
# Nearest to active: bookmakers, rj, proterozoic, ascetics, appellation, scorpio, tucum, osha,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9643 0.2344 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0452 0.2267 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0256 0.2745 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0394 0.2089 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0612 0.1963 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0266 0.1885 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0326 0.1939 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9938 0.2008 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0238 0.1996 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9584 0.1998 sec/batch
# Nearest to one: three, zero, seven, six, four, five, eight, nine,
# Nearest to called: the, wannsee, provincial, cotten, drenched, rip, weren, startled,
# Nearest to it: obligatory, microcontroller, salamanders, phase, voluntarily, explicated, capability, levelling,
# Nearest to seven: one, zero, two, eight, six, three, five, four,
# Nearest to there: present, palatable, are, surreal, convenience, tongs, upc, samoans,
# Nearest to these: cutting, mormon, ptb, enzymes, canton, disappeared, inconspicuous, kingship,
# Nearest to he: his, him, returned, alsatian, scruple, wished, shays, sonnet,
# Nearest to will: jumped, indent, ragged, messiahs, does, excised, sequentially, indelible,
# Nearest to marriage: mentally, beaumarchais, couples, bile, divorce, moran, romanorum, disgust,
# Nearest to consists: rede, parliament, dkp, zhdanov, landtag, vrije, hillsdale, hv,
# Nearest to behind: naturalised, overhead, logos, intersecting, advancing, apparent, erupts, heraclitus,
# Nearest to governor: aired, canada, hails, ilois, semantic, aravalli, syndicated, hates,
# Nearest to shown: trellis, numbers, huntley, fpga, ventral, prosigns, allenby, hyper,
# Nearest to operations: sauvage, assault, operation, numbers, tren, agencies, csm, gs,
# Nearest to heavy: unreactive, curtis, alpina, deuterium, phalanx, gilmour, guided, peopled,
# Nearest to active: bookmakers, proterozoic, ascetics, rj, appellation, scorpio, bonner, richards,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9830 0.2096 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9394 0.1968 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0168 0.1992 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0085 0.1996 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0213 0.1957 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9985 0.1984 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9001 0.2045 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9341 0.1941 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9297 0.2375 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9729 0.2407 sec/batch
# Nearest to one: three, zero, six, seven, four, five, nine, eight,
# Nearest to called: the, wannsee, it, provincial, activated, cotten, drenched, rip,
# Nearest to it: microcontroller, explicated, voluntarily, obligatory, called, decrease, phase, doublet,
# Nearest to seven: zero, one, two, eight, six, five, three, four,
# Nearest to there: are, surreal, present, palatable, convenience, average, samoans, swampy,
# Nearest to these: cutting, enzymes, mormon, disappeared, ptb, canton, inconspicuous, corelli,
# Nearest to he: his, him, returned, sonnet, wished, never, lenny, alsatian,
# Nearest to will: jumped, indent, excised, ragged, does, hijacked, sequentially, reach,
# Nearest to marriage: mentally, beaumarchais, divorce, couples, romanorum, bile, moran, gifs,
# Nearest to consists: rede, parliament, dkp, landtag, zhdanov, hv, side, vrije,
# Nearest to behind: overhead, naturalised, logos, advancing, intersecting, packers, redoutable, the,
# Nearest to governor: ilois, aired, canada, hails, aravalli, semantic, incrementally, mcm,
# Nearest to shown: trellis, numbers, allenby, huntley, pantone, prosigns, fpga, ventral,
# Nearest to operations: sauvage, numbers, operation, assault, csm, gs, agencies, encountered,
# Nearest to heavy: curtis, unreactive, alpina, phalanx, deuterium, markets, guided, gilmour,
# Nearest to active: bookmakers, rj, ascetics, proterozoic, osha, igad, fruitarians, scorpio,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9888 0.2182 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9802 0.2270 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 4.0078 0.2436 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0346 0.2342 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0211 0.2049 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9391 0.2022 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0102 0.2011 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9742 0.2033 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0086 0.2205 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9946 0.2136 sec/batch
# Nearest to one: three, zero, six, seven, four, five, eight, nine,
# Nearest to called: the, wannsee, rip, cotten, activated, sid, provincial, it,
# Nearest to it: voluntarily, obligatory, microcontroller, explicated, phase, doublet, hoarded, consent,
# Nearest to seven: one, zero, eight, two, six, three, five, four,
# Nearest to there: are, surreal, palatable, present, tongs, convenience, samoans, upc,
# Nearest to these: ptb, mormon, cutting, enzymes, beatboxing, canton, disappeared, corelli,
# Nearest to he: his, him, returned, wished, sonnet, alsatian, graduated, lenny,
# Nearest to will: jumped, indent, does, excised, ragged, messiahs, hijacked, sequentially,
# Nearest to marriage: mentally, couples, divorce, beaumarchais, bile, romanorum, disgust, moran,
# Nearest to consists: rede, parliament, dkp, zhdanov, landtag, multiplicity, side, hv,
# Nearest to behind: overhead, naturalised, logos, intersecting, onomatopoeic, erupts, advancing, packers,
# Nearest to governor: ilois, aired, hails, canada, aravalli, semantic, headroom, hates,
# Nearest to shown: trellis, numbers, huntley, allenby, prosigns, ventral, fpga, pantone,
# Nearest to operations: sauvage, numbers, agencies, assault, operation, csm, management, security,
# Nearest to heavy: unreactive, curtis, alpina, phalanx, deuterium, however, icsu, gilmour,
# Nearest to active: bookmakers, rj, proterozoic, ascetics, igad, osha, saddam, chair,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0076 0.2118 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9880 0.2193 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9823 0.1988 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9920 0.2112 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0187 0.2279 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0040 0.2482 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9661 0.2189 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9745 0.2015 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9755 0.2288 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0374 0.2111 sec/batch
# Nearest to one: three, zero, seven, six, five, four, eight, nine,
# Nearest to called: wannsee, the, provincial, differing, activated, sid, generalised, purbo,
# Nearest to it: voluntarily, obligatory, phase, microcontroller, that, explicated, consent, existence,
# Nearest to seven: one, zero, eight, two, six, five, three, four,
# Nearest to there: are, palatable, present, convenience, upc, samoans, surreal, tongs,
# Nearest to these: mormon, ptb, cutting, disappeared, canton, beatboxing, enzymes, tensions,
# Nearest to he: his, him, returned, sonnet, graduated, wished, circumnavigation, lenny,
# Nearest to will: jumped, indent, does, messiahs, excised, ragged, metres, coerce,
# Nearest to marriage: mentally, divorce, beaumarchais, couples, bile, gifs, disgust, romanorum,
# Nearest to consists: rede, parliament, dkp, zhdanov, landtag, hv, bicameral, multiplicity,
# Nearest to behind: naturalised, logos, overhead, intersecting, apparent, erupts, advancing, redoutable,
# Nearest to governor: ilois, aired, semantic, headroom, hails, canada, hates, aravalli,
# Nearest to shown: trellis, numbers, allenby, huntley, pantone, fpga, ventral, debacle,
# Nearest to operations: sauvage, agencies, assault, operation, csm, numbers, management, staff,
# Nearest to heavy: unreactive, deuterium, curtis, alpina, phalanx, gilmour, markets, beatnik,
# Nearest to active: bookmakers, proterozoic, rj, ascetics, osha, igad, scorpio, chair,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9817 0.2451 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0744 0.2461 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0165 0.2139 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0142 0.2180 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9634 0.2355 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9456 0.2286 sec/batch
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8759 0.3239 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8568 0.3602 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8291 0.3657 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8530 0.3062 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8900 0.3144 sec/batch
# Nearest to one: three, zero, seven, six, nine, five, four, two,
# Nearest to called: the, a, it, wannsee, of, sid, acronyms, or,
# Nearest to it: that, this, the, to, a, is, called, because,
# Nearest to seven: one, zero, eight, six, five, three, two, four,
# Nearest to there: are, is, have, of, for, a, many, only,
# Nearest to these: are, in, include, of, most, individually, both, ones,
# Nearest to he: his, him, returned, was, graduated, lecturer, semester, sonnet,
# Nearest to will: does, jumped, indent, we, contact, even, everything, die,
# Nearest to marriage: divorce, requirement, marriages, couples, mentally, married, comarca, marry,
# Nearest to consists: rede, hv, landtag, branches, elects, multiplicity, or, the,
# Nearest to behind: succinct, up, advancing, redoutable, restlessness, the, willughby, naturalised,
# Nearest to governor: aired, ilois, incrementally, semantic, syndicated, hails, mcm, headroom,
# Nearest to shown: numbers, trellis, details, pbs, duchenne, allenby, huntley, fpga,
# Nearest to operations: sauvage, numbers, intellivision, relocate, csm, management, dynamically, database,
# Nearest to heavy: deuterium, gilmour, however, unreactive, stimulants, cofactors, methylphenidate, curtis,
# Nearest to active: proterozoic, ascetics, facilitating, nomos, ut, inositol, osha, flensburg,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8310 0.3228 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8605 0.3396 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8220 0.3289 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8659 0.3123 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8540 0.3094 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8720 0.3270 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8515 0.3200 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8459 0.3594 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8784 0.3188 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8518 0.3177 sec/batch
# Nearest to one: three, zero, seven, nine, five, two, eight, four,
# Nearest to called: wannsee, the, it, a, purbo, sid, generalised, rescind,
# Nearest to it: that, this, the, is, a, to, in, called,
# Nearest to seven: one, zero, eight, five, six, three, two, four,
# Nearest to there: are, have, of, many, is, for, only, a,
# Nearest to these: are, in, most, include, of, mentored, numerous, both,
# Nearest to he: his, him, returned, was, graduated, lecturer, worked, studied,
# Nearest to will: does, indent, we, contact, jumped, everything, messiahs, sinking,
# Nearest to marriage: divorce, married, marriages, requirement, couples, mentally, bile, wedding,
# Nearest to consists: rede, the, or, landtag, hv, multiplicity, elects, branches,
# Nearest to behind: up, willughby, succinct, net, naturalised, reflectance, restlessness, melded,
# Nearest to governor: ilois, aired, incrementally, semantic, hails, headroom, prefects, syndicated,
# Nearest to shown: numbers, pbs, duchenne, allenby, details, trellis, fpga, shows,
# Nearest to operations: sauvage, numbers, relocate, operation, csm, intellivision, agencies, management,
# Nearest to heavy: however, deuterium, stimulants, unreactive, khazaria, gilmour, woolton, phalanx,
# Nearest to active: proterozoic, facilitating, ascetics, ut, inositol, flensburg, hazing, polycarp,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8572 0.3629 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8365 0.3114 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8163 0.3036 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8327 0.3090 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8994 0.3144 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8515 0.3339 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9589 0.3054 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8823 0.3180 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9460 0.3241 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8088 0.3097 sec/batch
# Nearest to one: three, zero, seven, two, six, eight, nine, five,
# Nearest to called: wannsee, acronyms, purbo, the, a, rescind, sid, generalised,
# Nearest to it: that, the, this, is, in, a, became, to,
# Nearest to seven: one, eight, zero, six, five, three, two, four,
# Nearest to there: are, have, of, is, many, for, only, a,
# Nearest to these: are, most, in, include, bsec, both, several, and,
# Nearest to he: his, returned, graduated, was, him, lecturer, worked, studied,
# Nearest to will: does, we, everything, indent, ragged, jumped, messiahs, contact,
# Nearest to marriage: divorce, marriages, couples, married, wedding, requirement, mentally, bile,
# Nearest to consists: rede, the, elects, landtag, branches, hv, branch, comprises,
# Nearest to behind: naturalised, up, succinct, willughby, melded, juliana, advancing, restlessness,
# Nearest to governor: aired, ilois, semantic, incrementally, hails, mcm, syndicated, headroom,
# Nearest to shown: numbers, duchenne, details, pbs, same, allenby, shows, trellis,
# Nearest to operations: sauvage, agencies, relocate, numbers, csm, intellivision, operation, dynamically,
# Nearest to heavy: however, deuterium, stimulants, gilmour, woolton, unreactive, khazaria, idiopathic,
# Nearest to active: facilitating, proterozoic, ascetics, flensburg, nomos, klan, catalunya, clairvaux,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8048 0.3350 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8590 0.3345 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8053 0.3104 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8633 0.3234 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8435 0.3046 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8564 0.3773 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8897 0.2143 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8295 0.3533 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7871 0.4111 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8704 0.3854 sec/batch
# Nearest to one: three, seven, zero, nine, eight, five, four, two,
# Nearest to called: wannsee, the, a, acronyms, sid, group, purbo, generalised,
# Nearest to it: that, the, this, to, a, is, most, posit,
# Nearest to seven: one, eight, zero, five, six, three, four, two,
# Nearest to there: are, have, is, many, of, for, a, only,
# Nearest to these: are, include, most, in, several, ones, bsec, both,
# Nearest to he: his, him, was, returned, graduated, lecturer, after, took,
# Nearest to will: we, does, everything, jumped, ragged, messiahs, sinking, indent,
# Nearest to marriage: divorce, marriages, requirement, married, couples, marry, mut, wedding,
# Nearest to consists: rede, elects, branches, comprises, landtag, the, branch, datagram,
# Nearest to behind: up, succinct, willughby, advancing, reflectance, juliana, melded, restlessness,
# Nearest to governor: aired, ilois, semantic, incrementally, syndicated, hails, headroom, mcm,
# Nearest to shown: numbers, duchenne, same, allenby, pbs, details, shows, examples,
# Nearest to operations: sauvage, numbers, csm, relocate, invented, tenses, intellivision, operation,
# Nearest to heavy: deuterium, woolton, gilmour, stimulants, however, unreactive, khazaria, curtis,
# Nearest to active: facilitating, proterozoic, nomos, ascetics, flensburg, polycarp, northeasterly, klan,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8108 0.3838 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8103 0.3697 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8155 0.3616 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8603 0.3563 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8657 0.3558 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8620 0.3350 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8822 0.3785 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7112 0.3607 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8320 0.3582 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7626 0.3566 sec/batch
# Nearest to one: three, zero, seven, four, nine, five, two, six,
# Nearest to called: a, the, wannsee, or, it, purbo, acronyms, of,
# Nearest to it: that, the, this, a, to, is, in, most,
# Nearest to seven: one, zero, eight, six, five, three, four, two,
# Nearest to there: are, is, have, for, a, of, many, any,
# Nearest to these: are, in, include, most, ones, several, and, other,
# Nearest to he: his, returned, him, was, graduated, lecturer, took, gave,
# Nearest to will: we, does, jumped, sinking, contact, indent, everything, even,
# Nearest to marriage: divorce, marriages, requirement, married, marry, couples, wedding, marrying,
# Nearest to consists: the, elects, rede, comprises, branch, branches, hv, or,
# Nearest to behind: succinct, advancing, willughby, reflectance, net, naturalised, restlessness, juliana,
# Nearest to governor: aired, ilois, semantic, incrementally, syndicated, hails, headroom, mcm,
# Nearest to shown: numbers, duchenne, same, allenby, pbs, details, shows, huntley,
# Nearest to operations: sauvage, numbers, relocate, csm, operation, invented, tenses, agencies,
# Nearest to heavy: deuterium, gilmour, stimulants, unreactive, woolton, however, phalanx, methylphenidate,
# Nearest to active: facilitating, proterozoic, northeasterly, ascetics, catalunya, nomos, polycarp, igad,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7650 0.3656 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8341 0.3607 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8785 0.3904 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8239 0.4324 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8408 0.3820 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8990 0.3865 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8085 0.3098 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8255 0.3087 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8242 0.3041 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8308 0.3314 sec/batch
# Nearest to one: three, zero, seven, nine, five, two, six, four,
# Nearest to called: a, the, wannsee, acronyms, of, it, sid, or,
# Nearest to it: that, this, the, a, to, is, in, called,
# Nearest to seven: one, zero, eight, three, five, six, four, two,
# Nearest to there: are, have, for, is, a, any, many, of,
# Nearest to these: are, include, in, most, ones, bsec, and, other,
# Nearest to he: his, returned, him, was, graduated, lecturer, worked, gave,
# Nearest to will: indent, we, does, contact, jumped, everything, messiahs, sinking,
# Nearest to marriage: divorce, marriages, married, marrying, requirement, couples, marry, wedding,
# Nearest to consists: the, rede, comprises, serve, elects, branch, or, branches,
# Nearest to behind: succinct, reflectance, advancing, net, up, willughby, enlarged, juliana,
# Nearest to governor: ilois, aired, semantic, incrementally, hails, syndicated, governors, headroom,
# Nearest to shown: numbers, duchenne, details, pbs, shows, same, allenby, on,
# Nearest to operations: sauvage, numbers, relocate, csm, management, agencies, operation, intellivision,
# Nearest to heavy: deuterium, stimulants, gilmour, woolton, however, unreactive, beatnik, methylphenidate,
# Nearest to active: facilitating, ascetics, proterozoic, polycarp, catalunya, premiered, hazing, northeasterly,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8781 0.3633 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8639 0.3225 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8177 0.3173 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8342 0.3257 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8671 0.3031 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8378 0.3066 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8523 0.3088 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8641 0.3084 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8085 0.3282 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8209 0.3035 sec/batch
# Nearest to one: three, zero, five, nine, seven, two, eight, six,
# Nearest to called: wannsee, the, a, purbo, are, acronyms, sid, some,
# Nearest to it: the, that, in, a, this, to, is, most,
# Nearest to seven: one, eight, zero, three, five, six, four, two,
# Nearest to there: are, for, have, is, a, many, of, only,
# Nearest to these: are, in, include, and, ones, most, several, numerous,
# Nearest to he: his, returned, him, lecturer, was, graduated, worked, studied,
# Nearest to will: does, we, indent, you, messiahs, even, everything, contact,
# Nearest to marriage: divorce, marriages, marrying, married, couples, requirement, wedding, marry,
# Nearest to consists: the, elects, comprises, branches, hv, branch, rede, serve,
# Nearest to behind: advancing, reflectance, willughby, succinct, up, juliana, naturalised, net,
# Nearest to governor: ilois, aired, incrementally, semantic, syndicated, governors, headroom, hails,
# Nearest to shown: numbers, details, duchenne, same, pbs, shows, allenby, on,
# Nearest to operations: sauvage, relocate, csm, operation, numbers, agencies, tenses, management,
# Nearest to heavy: stimulants, deuterium, beatnik, woolton, unreactive, gilmour, however, purpose,
# Nearest to active: facilitating, flensburg, ascetics, inositol, northeasterly, catalunya, today, hazing,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8555 0.3083 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8062 0.3074 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9408 0.3035 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8621 0.3079 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8734 0.3036 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7966 0.3055 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7850 0.3008 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8265 0.3057 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7704 0.3064 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8398 0.3071 sec/batch
# Nearest to one: nine, three, zero, seven, five, eight, four, two,
# Nearest to called: a, wannsee, the, group, acronyms, purbo, are, generalised,
# Nearest to it: that, this, the, to, a, is, in, most,
# Nearest to seven: one, eight, zero, five, six, four, three, two,
# Nearest to there: are, have, is, a, many, for, only, of,
# Nearest to these: are, include, ones, in, most, several, and, there,
# Nearest to he: his, returned, him, was, graduated, lecturer, after, studied,
# Nearest to will: we, contact, everything, messiahs, does, indent, jumped, ragged,
# Nearest to marriage: divorce, marriages, requirement, married, marrying, wedding, couples, mut,
# Nearest to consists: branch, the, elects, rede, comprises, branches, hv, serve,
# Nearest to behind: reflectance, advancing, up, juliana, willughby, succinct, restlessness, enlarged,
# Nearest to governor: aired, ilois, semantic, incrementally, syndicated, governors, mcm, hails,
# Nearest to shown: numbers, duchenne, details, same, pbs, shows, allenby, huntley,
# Nearest to operations: sauvage, operation, csm, relocate, agencies, numbers, tenses, sassanian,
# Nearest to heavy: woolton, stimulants, deuterium, beatnik, gilmour, curtis, unreactive, hardcore,
# Nearest to active: facilitating, flensburg, catalunya, shaky, college, polycarp, proterozoic, today,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8474 0.3130 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8265 0.3230 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
